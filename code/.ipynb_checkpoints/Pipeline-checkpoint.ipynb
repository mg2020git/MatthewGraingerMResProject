# %% [markdown]
# Summary of 'Replaying the tape of ecology to domesticate wild microbiota'
# =====
# My research project uses data from 'Replaying the tape of ecology to domesticate wild microbiota'. Below is a summary of this paper:
#
# #### Research questions answered:
#     - Can bacterial community assembly be reproduced?
#     - Do reproduced bacterial communities confer the same function?
#
# #### Experiment:
#     - 275 starting communities, each from a unique tree hole
#     - Different initial taxonomic compositions
#     - Composition of these starting communities before cryopreservation
#     - After cryopreservation, 4 replicates for each of 275 starting communities, standardised environment for 7 days, then sample composition
#     - Communities associated with leaf litter degradation function
#
# #### Techniques used:
#     - Identified that the 4 final community replicates of each of the 275 tree holes were clustered
#     - Used ordination to track changes in abundance of taxa, showing that cirection of travel from starting to final communities consistent among communities and replicates
#     - Unsupervised clustering of communities based on composition - 5 initial classes, 2 final classes
#     - Metagenomic predictions of functional differences between classes: identify associations between 2 final community classes and functional performance of communities by inputting metagenomes of communities from 16S rRNA sequencing data, using PiCRUST to categorise genes by function using the KEGG database - find out what aorts of genes the community classes have in terms of what the genes do ex. take up nutrients
#     - Direct measurements of functional performance of final communities: degradation rate of 4 substrates, whole community metabolic activity, respiration rate, and cell numbers.

# %% [markdown]
# My biological research question:
# ======
# ### How do differences in the network structure of microbial communities link to function?

# %% [markdown]
# How can this be achieved?
# =====
#
# #### Co-occurrence network options
#
# Co-occurrence network of starting communities:
# There are 2 options...
#
# - OPTION 1: Because there are no replicates for the starting communities of a given tree hole, only one co-occurrence network can be constructed across the starting communities of all of the tree holes.
#
# - OPTION 2: Separate the tree holes according to community class, and construct co-occurrence networks for each class (5 in total).
#
# Co-occurrence network of final communities:
# There are 3 options...
#
# - OPTION 1: Calculate a co-occurrence network across all tree holes for each final community replicate. This would result in 4 co-occurrence networks. The co-occurrence network for final community replicate 1, for instance, would be across the replicate 1 final communities for all 275 tree holes. Could also do the same, whilst ignoring replicates, resulting in a network across 4 replicates of the 275 tree holes (1100 samples) - this seems a bit strange as the number of samples between this network and the starting network are mismatched.
#
# - OPTION 2: Because there are 4 replicate final communities for every tree hole (and thus every starting community), it is possible to create a co-occurrence network for each tree hole across its 4 replicates. This would result in 275 co-occurrence networks. Unlike in the starting community co-occurrence network and in OPTION 1, here we would be calculating co-occurrence across replicates of a single tree hole, rather than co-occurrence across multiple tree holes. I am not sure how comparable this would be to the starting network, given that the starting tree holes are heterogeneous, so they seemingly cannot be generalised to replicates.
#
# - OPTION 3: Separate the tree holes according to community class and replicate, and construct a co-occurrence network for each class within each replicate (8 total because 2 community classes in each of 4 replicates).
#
# #### Narrowing down the options
# - I think that OPTION 2 for the starting community co-occurrence network and OPTION 3 for the final community co-occurrence network are the best options. Because the function of the community classes are known, the functions of the networks constructed within the community classes will also be known. The structure of the networks in the different classes can then be compared in relation to this function
# - PROBLEM: How does this add to the previous paper? What can we use to compare network structure in a biologically meaningful way. I am confused about what additional information constructing a network adds to the existing information upon community composition that is available for each community class.
#
# - ALTERNATIVE:
# - Could use final community OPTION 2 to get a co-occurrence network for each tree hole, and then compare these co-occurrence network structures in relation to the known function of each sample. Here, we would either ignore the starting communities altogether, or treat them as a single tree hole - whereby each individual tree hole starting communtiy would be treated as a replicate as an overall meta-treehole.
# - PROBLEM: The starting tree hole communities were different, so there wasn't really a single starting poitn for all of the final communities
# - PROBLEM: Still need to find out what network features to comaprei n a biologically meaningful way, and how this adds to the previosu paper.
#
# #### Current choice:
# - I have currently chosen OPTION 2 for the starting community co-occurrence network and OPTION 3 for the final community co-occurrence network - I will split the data by samples and replicate, and construct co-occurrence network for each combination.
#
# #### What to compare between networks for biological meaning
# - Main question is what to compare between networks for biological meaning. We already know the composition of each community class, and so we already know the composition of each network (assuming we pick the combination of starting community OPTION 2 and final communtiy OPTION 3). What can we compare that provides additional information. Here are some options:
#     - Number of links
#     - Topology
#     - Central species
#     - Presence and types of communities

# %% [markdown]
# Pipeline
# ======
# This is the pipeline for Matthew Shaun Grainger's MRes Research Project.
# Overall, it involves constructing co-occurrence networks for each class of each replicate of the starting and final microbial communities, and then comparing the structures of these networks.

# %% [markdown]
# ## 1. Preliminaries
# 1. Importing all of the data from the treeholes paper
# 2. Familiarizing myself with the data, in particular with the metadata. Extracting the communities that I will be working with.
# 3. Installing FlashWeave, and making it work. So far, it seems to outperform other methods.

# %% [markdown]
# #### 1) Importing all of the data from the treeholes paper
# The below code is written in Python - be sure to switch to the Python kernel to run it!

# %%
# Importing packages
import pandas as pd

# Importing ASV table
asv_table = pd.read_csv('../data/seqtable_readyforanalysis.csv', sep='\t')
# Importing metadata
metadata = pd.read_csv('../data/metadata_Time0D-7D-4M_May2022_wJSDpart_ext.csv', sep='\t')
# Importing taxonomy
taxonomy_data = pd.read_csv('../data/taxa_wsp_readyforanalysis.csv', sep='\t')

# %% [markdown]
# #### 2) Familiarizing myself with the data, in particular with the metadata. Extracting the communities that I will be working with.
# The below code is written in Python - be sure to switch to the Python kernel to run it!

# %% [markdown]
# ##### ASV Table
# The ASV table is in the standard format. There is a column for each ASV, and there is a row for each sample. Each cell contains the abundance of an OTU in a given sample.

# %%
# Looking at the ASV table
asv_table

# %% [markdown]
# ##### Metadata
# The metadata contains a row for each sample. It has columns which provide additional information about each sample. Out of these columns, the following are relevant:
# - sampleid: Each sample has an unique ID
# - replicate: Replicate of the experiment. Starting communities are labelled as Rep0
# - parent: ID of the starting communities from which final communities departed. For example, final community with id WYT14.1 is the replicate 1 of starting community WYT14, which is the ID indicated in this field.
# - Location: Sampling field from which the starting communities were sampled.
# - Experiment: Either starting communities (0D) or final communities (7D_rep$) were "$" = 1-4 depending on the replicate. Samples belonging to experiment 4M should be ignored.
# - Part_Time0D_17: Id of the class the starting communities belong to, corresponding to the maximum of the Calinski-Harabasz index found considering starting communities only. (1 to 17 and NA for samples not belonging to the set)
# - Part_Time0D_6: Id of the class the starting communities belong to, corresponding to the second maximum of the Calinski-Harabasz index found considering starting communities only (analysed in this work) (runs from 1 to 6 and NA for samples not belonging to the set)
# - Part_Time7D_rep1_2: Id of the class the first replicate of final communities belong to, corresponding to the maximum of the Calinski-Harabasz index. (1 to 2 and NA for samples not belonging to the set)
# - Part_Time7D_rep2_2: Id of the class the second replicate of final communities belong to, corresponding to the maximum of the Calinski-Harabasz index. (1 to 2 and NA for samples not belonging to the set)
# - Part_Time7D_rep3_2: Id of the class the third replicate of final communities belong to, corresponding to the maximum of the Calinski-Harabasz index. (1 to 2 and NA for samples not belonging to the set)
# - Part_Time7D_rep4_2: Id of the class the fourth replicate of final communities belong to, corresponding to the maximum of the Calinski-Harabasz index. (1 to 2 and NA for samples not belonging to the set)
# - replicate.partition: Combination of the replicate and partition ids. Note that the ids obtained for each replicate independently (1 and 2 for each replicate) can be considered paired across replicates, since we showed they have similar compositions. Also note that Rep0.Class1 and Rep0.Class2 are ids used in Experiments 0D and 4M. Therefore, those belonging to Experiment = 4M should be ignored.
# - partition: Only the class. As in the previous field, one should exclude samples in Experiment = 4M.
# - ExpCompact: Another identifier for the experiment, in which the 4 replicates of final communities have the same id (note that in the field Experiment the different replicates were differentiated). Levels are Starting, Final (and Evolved should be excluded).
# - exp.replicate.partition: Combination of ExpCompact, and replicate.partition
# - exp.partition: Combination of ExpCompact, and partition

# %%
# Looking at the metadata
metadata

# %%
# The names of the columns in the metadata
print(metadata.columns)

# %%
print(metadata['replicate.partition'].value_counts())

# %%
print(metadata['exp.replicate.partition'].value_counts())

# %% [markdown]
# Taxonomy

# %%
taxonomy_data

# %% [markdown]
# #### Extracting the communities that I will be working with:

# %%
# Getting rid of the samples belonging to experiment 4M:
asv_table.reset_index(inplace=True) # Making the sample ID into a column for the ASV table
asv_table.rename(columns={'index': 'sampleid'}, inplace=True) # renaming this new column to 'sampleid'
metadata_asv_table = pd.merge(asv_table, metadata, on='sampleid') # Merging metadata and asv_table by 'sampleid'
main_data = metadata_asv_table[metadata_asv_table['Experiment'] != '4M'] # Taking rows which are not 4M samples

# Separating the samples by class and replicate (a separate data frame for each class within each replicate).
starting_class1 = main_data[main_data['exp.replicate.partition'] == 'Starting.Rep0.Class1']
starting_class2 = main_data[main_data['exp.replicate.partition'] == 'Starting.Rep0.Class2']
starting_class3 = main_data[main_data['exp.replicate.partition'] == 'Starting.Rep0.Class3']
starting_class4 = main_data[main_data['exp.replicate.partition'] == 'Starting.Rep0.Class4']
starting_class5 = main_data[main_data['exp.replicate.partition'] == 'Starting.Rep0.Class5']
starting_class6 = main_data[main_data['exp.replicate.partition'] == 'Starting.Rep0.Class6']

final1_class1 = main_data[main_data['exp.replicate.partition'] == 'Final.Rep1.Class1']
final1_class2 = main_data[main_data['exp.replicate.partition'] == 'Final.Rep1.Class2']
final2_class1 = main_data[main_data['exp.replicate.partition'] == 'Final.Rep2.Class1']
final2_class2 = main_data[main_data['exp.replicate.partition'] == 'Final.Rep2.Class2']
final3_class1 = main_data[main_data['exp.replicate.partition'] == 'Final.Rep3.Class1']
final3_class2 = main_data[main_data['exp.replicate.partition'] == 'Final.Rep3.Class2']
final4_class1 = main_data[main_data['exp.replicate.partition'] == 'Final.Rep4.Class1']
final4_class2 = main_data[main_data['exp.replicate.partition'] == 'Final.Rep4.Class2']

# Removing metadata columns
columns_to_drop = ['sampleid', 'Name.2', 'Community', 'Species', 'replicate',
       'BreakingBag', 'parent', 'Location', 'Experiment', 'Part_Time0D_17',
'Community', 'Species', 'replicate',
       'BreakingBag', 'parent', 'Location', 'Experiment', 'Part_Time0D_17',
       'Part_Time0D_6', 'Part_Time4M_64', 'Part_Time7D_rep1_2',
       'Part_Time7D_rep2_2', 'Part_Time7D_rep3_2', 'Part_Time7D_rep4_2',
       'replicate.partition', 'partition', 'ExpCompact',
       'exp.replicate.partition', 'exp.partition', 'Part_Time0D_6', 'Part_Time4M_64', 'Part_Time7D_rep1_2',
       'Part_Time7D_rep2_2', 'Part_Time7D_rep3_2', 'Part_Time7D_rep4_2',
       'replicate.partition', 'partition', 'ExpCompact',
       'exp.replicate.partition', 'exp.partition']

starting_class1 = starting_class1.drop(columns=columns_to_drop)
starting_class2 = starting_class2.drop(columns=columns_to_drop)
starting_class3 = starting_class3.drop(columns=columns_to_drop)
starting_class4 = starting_class4.drop(columns=columns_to_drop)
starting_class5 = starting_class5.drop(columns=columns_to_drop)
starting_class6 = starting_class6.drop(columns=columns_to_drop)

final1_class1 = final1_class1.drop(columns=columns_to_drop)
final1_class2 = final1_class2.drop(columns=columns_to_drop)
final2_class1 = final2_class1.drop(columns=columns_to_drop)
final2_class2 = final2_class2.drop(columns=columns_to_drop)
final3_class1 = final3_class1.drop(columns=columns_to_drop)
final3_class2 = final3_class2.drop(columns=columns_to_drop)
final4_class1 = final4_class1.drop(columns=columns_to_drop)
final4_class2 = final4_class2.drop(columns=columns_to_drop)

# Creating .csv files for each of these subsets.
# This code is not intended to be reproducible, so it does not need to be super efficient.
# The easiest way to acccess these Python-created subsets in Julia, where Flashweave is coded, is to import them from .csv files.
starting_class1.to_csv('../data/starting_class1.csv', index=False)
starting_class2.to_csv('../data/starting_class2.csv', index=False)
starting_class3.to_csv('../data/starting_class3.csv', index=False)
starting_class4.to_csv('../data/starting_class4.csv', index=False)
starting_class5.to_csv('../data/starting_class5.csv', index=False)
starting_class6.to_csv('../data/starting_class6.csv', index=False)

final1_class1.to_csv('../data/final1_class1.csv', index=False)
final1_class2.to_csv('../data/final1_class2.csv', index=False)
final2_class1.to_csv('../data/final2_class1.csv', index=False)
final2_class2.to_csv('../data/final2_class2.csv', index=False)
final3_class1.to_csv('../data/final3_class1.csv', index=False)
final3_class2.to_csv('../data/final3_class2.csv', index=False)
final4_class1.to_csv('../data/final4_class1.csv', index=False)
final4_class2.to_csv('../data/final4_class2.csv', index=False)

# %%
starting_class5

# %% [markdown]
# #### 3) Installing FlashWeave, and making it work. So far, it seems to outperform other methods.

# %% [markdown]
# Installed FlashWeave.
# FlashWeave is programmed within Julia - please make sure to switch to the Julia kernel to run the below code.

# %% [markdown]
# ### 2. Infer networks

# %%
using FlashWeave
data_path = "../data/final1_class1.csv"
netw_results = learn_network(data_path, sensitive=true, heterogeneous=false)
# Out:
# ### Loading data ###
#
# ### Normalizing ###
#
# Removing variables with 0 variance (or equivalently 1 level) and samples with 0 reads
# 	-> discarded 0 samples and 567 variables
#
# Normalization
#
# ### Learning interactions ###
#
# Inferring network with FlashWeave - sensitive (conditional)
#
# 	Run information:
# 	sensitive - true
# 	heterogeneous - false
# 	max_k - 3
# 	alpha - 0.01
# 	sparse - false
# 	workers - 1
# 	OTUs - 901
# 	MVs - 0
#
# Automatically setting 'n_obs_min' to 20 for enhanced reliability
# Computing univariate associations
#
# Univariate degree stats:
# Summary Stats:
# Length:         901
# Missing Count:  0
# Mean:           27.738069
# Minimum:        1.000000
# 1st Quartile:   13.000000
# Median:         20.000000
# 3rd Quartile:   36.000000
# Maximum:        129.000000
#
#
#
# Starting conditioning search
#
# Preparing workers..
#
# Done. Starting inference..
# Starting convergence checks at 2437 edges.
# Latest convergence step change: 0.31253
# Latest convergence step change: 0.54347
# Latest convergence step change: 0.09666
# Latest convergence step change: 0.0
# 	CONVERGED! Waiting for the remaining processes to finish their current load.
#
# Postprocessing
# Complete
#
# Finished inference. Total time taken: 12.543s
# Mode:
# FlashWeave - sensitive (conditional)
#
# Network:
# 2692 interactions between 901 variables (901 OTUs and 0 MVs)
#
# Unfinished variables:
# none
#
# Rejections:
# not tracked

# %%
save_network("../data/final1_class1_network_output.edgelist", netw_results)

# %% [markdown]
# ### Applying functionInk

# %% [markdown]
# First, modifying the format of the output of FlashWeave to match the input format for functionInk.
# Please switch to the Python kernel to run the code below.

# %%
import pandas as pd # Importing Pandas again, as switched back to Python kernel

# Removing the headers
with open('../data/final1_class1_network_output.edgelist', 'r') as f:
    lines = f.readlines()
with open('../data/final1_class1_network_output.edgelist', 'w') as f:
    f.writelines(lines[2:])

# Adding new headers and a column for the type if interaction (here, all assumed to be the same)
final1_class1_network_data = pd.read_csv("../data/final1_class1_network_output.edgelist", sep="\t", header=None, names=["ASV_A", "ASV_B", "Interaction"])
final1_class1_network_data['Type'] = 1

# Outputting as a .tsv
final1_class1_network_data.to_csv('../data/final1_class1_network_data.tsv', sep='\t', index=False, header=['#ASV_A', 'ASV_B', 'Interaction', 'Type'])

# %% [markdown]
# Next, running the detailed pipeline for functionInk, as described in its vignette.

# %%
%cd functionInk # Moving to the functionInk repositroy to run its commands
# Out:
# /home/matthew/Documents/ResearchProject/ResearchProjectRepository/code/functionInk

# %%
# The first step to the pipeline - computing similarities between nodes
!./NodeSimilarity.pl -w 1 -d 0 -t 0 -f ../../data/final1_class1_network_data.tsv
# Out:
#
# **************************************************
# * Building nodes similarities NodeSimilarity.pl  *
# **************************************************
#
# >> Reading input arguments:
# ~~~ The network is weighted=1 or 2/unweighted=0? Value = 1
# ~~~ The network is directed=1/undirected=0? Value = 0
# ~~~ The network has different types=1/or a single type=0? Value = 0
# ~~~ The network file is = ../../data/final1_class1_network_data.tsv
#
# >> Processing input arguments:
# ~~~ Reading Node A from column 1
# ~~~ Reading Node B from column 2
# ~~~ Working with a weighted network -- Tanimoto coefficient
# ~~~ Reading weights from column 3
# ~~~ Working with a network with a single type of link
#
# ~~~ Input path:  ../../data/final1_class1_network_data.tsv
# ~~~ Input file:  final1_class1_network_data.tsv
#
#
# >> Reading the network:
# ~~~ The first lines for the fields read from file and after conversions are:
# ..Skip header:  1
# ~~~ Reading fields: nodeA = ASV_17,nodeB= ASV_20, type= 1, weight = 0.2406388675505882,
# ~~~ Reading fields: nodeA = ASV_13,nodeB= ASV_21, type= 1, weight = -0.2238145105285399,
# ~~~ Reading fields: nodeA = ASV_17,nodeB= ASV_21, type= 1, weight = -0.1859558905013027,
# ~~~ Reading fields: nodeA = ASV_1,nodeB= ASV_22, type= 1, weight = 0.1883744098541252,
# ~~~ Reading fields: nodeA = ASV_8,nodeB= ASV_22, type= 1, weight = 0.2561344504356384,
# ~~~ Reading fields: nodeA = ASV_9,nodeB= ASV_22, type= 1, weight = 0.2077235572916807,
# ~~~ Reading fields: nodeA = ASV_19,nodeB= ASV_22, type= 1, weight = 0.2200918044692875,
# ~~~ Reading fields: nodeA = ASV_19,nodeB= ASV_23, type= 1, weight = 0.1955423759700825,
# ~~~ Reading fields: nodeA = ASV_3,nodeB= ASV_24, type= 1, weight = 0.5191225451821149,
# ~~~ Reading fields: nodeA = ASV_9,nodeB= ASV_24, type= 1, weight = 0.3610989873106303,
# ~~~ The number of edges is:  2678
# ~~~ The number of nodes is:  901
#
#
#  >> Pre-processing coefficients
#
#
#  >> Start main computation
# ~~~ Computing similarities between nodes...
# ~~~ I have already processed 25% of the nodes!
# ~~~ I have already processed 50% of the nodes!
# ~~~ I have already processed 75% of the nodes!
# ~~~ Done!
#
# ****************************
# ** Program finished
# ** Check your results
# ** Bye!
# ****************************

# %%
# The second step - clustering nodes using the similarity metrics calculated
!./NodeLinkage.pl -fn ../../data/final1_class1_network_data.tsv -fs Nodes-Similarities_final1_class1_network_data.tsv
# Out:
# >> Reading input arguments:
# ~~~ The network file is = ../../data/final1_class1_network_data.tsv
# ~~~ The similarity file is = Nodes-Similarities_final1_class1_network_data.tsv
# ~~~ The clustering will run until
# ~~~~ we get a single cluster
# ~~~ Reading the similarity from column  = 3
# ~~~ Clustering with = Average
#
# ***********************************************
# * Finding communities with nodes clustering   *
# ***********************************************
#
# ~~ FIELDS for the FIRST FILE
# ~~~ Reading Node A from column 1
# ~~~ Reading Node B from column 2
# ~~~ Reading Similarities from column 3
# ~~ FIELDS for the SECOND FILE
# ~~~ Reading Node A from column 1
# ~~~ Reading Node B from column 2
# ~~~ Reading Similarities from column 3
# ~~ CLUSTERING parameters:
# ~~~ Performing a clustering with Average Linkage method
# ~~~ Clustering with no stopping point
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ~~ Opening the first input file:
# ~~~ Input path:  Nodes-Similarities_final1_class1_network_data.tsv
# ~~~ Input file:  Nodes-Similarities_final1_class1_network_data.tsv
# ~~~ Label for outputs:  _final1_class1_network_data.tsv
#
# ~~ Opening the second input file:
# ~~~ Input path:  ../../data/final1_class1_network_data.tsv
# ~~~ Input file:  final1_class1_network_data.tsv
# ~~~ Label for outputs:  .out
#
# ..Skip header:  1
#
# ~~~ The number of nodes to cluster is:  902
# ~~~ The number of edges in the network is:  2679
# ..Skip header:  1
# ..Skip header:  1
# ..Skip header:  1
# ..Skip header:  1
# ..Skip header:  1
# ..Skip header:  1
# ~~~ The maximum value found is: 0.489273771223044 for pair ASV_1272XXXXASV_1249
#
# *************************
#  STARTING CLUSTERING...
# *************************
#
# ** JOINING: *************************
# ASV_1272 ASV_1249
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  1 0.489273771223044
#  ::: Nodes  ASV_1272 ASV_1249 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 3 / 7
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 7
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 3 / 7
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 9
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 8
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1231 ASV_872
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  2 0.466195553937799
#  ::: Nodes  ASV_1231 ASV_872 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 3 / 10
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 10
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 3 / 10
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 12
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 11
#  ::: Number of external Edges A+B: 11
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_279 ASV_715
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  3 0.463888340205214
#  ::: Nodes  ASV_279 ASV_715 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 6 / 7
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 6 / 7
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 6 / 7
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 12
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 10
#  ::: Number of external Edges A+B: 11
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_881 ASV_813
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  4 0.45242358180895
#  ::: Nodes  ASV_881 ASV_813 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 4 / 5
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 4 / 5
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 4 / 5
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 9
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 7
#  ::: Number of external Edges A+B: 9
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1075 ASV_1368
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  5 0.451574517618456
#  ::: Nodes  ASV_1075 ASV_1368 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 2
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 2
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 2
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 3
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 1
#  ::: Number of external Edges A+B: 2
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_815 ASV_962
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  6 0.444632110906494
#  ::: Nodes  ASV_815 ASV_962 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 5 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 5 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 5 / 4
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 8
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 7
#  ::: Number of external Edges A+B: 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1310 ASV_458
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  7 0.438459127159751
#  ::: Nodes  ASV_1310 ASV_458 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 5 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 5 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 5 / 3
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 8
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 7
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1065 ASV_177
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  8 0.429488083210294
#  ::: Nodes  ASV_1065 ASV_177 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 5 / 8
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 5 / 8
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 5 / 8
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 12
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 9
#  ::: Number of external Edges A+B: 11
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_296 ASV_376
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  9 0.423539228789775
#  ::: Nodes  ASV_296 ASV_376 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 6
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 6
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 6
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 7
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 6
#  ::: Number of external Edges A+B: 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1116 ASV_1252
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  10 0.422022244818784
#  ::: Nodes  ASV_1116 ASV_1252 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 4
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 6
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 5
#  ::: Number of external Edges A+B: 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_280 ASV_842
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  11 0.420297825310342
#  ::: Nodes  ASV_280 ASV_842 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 3 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 3 / 4
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 7
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 6
#  ::: Number of external Edges A+B: 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_106 ASV_41
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  12 0.412994019544521
#  ::: Nodes  ASV_106 ASV_41 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 3 / 5
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 5
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 3 / 5
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 8
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 6
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_305 ASV_731
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  13 0.407002364058263
#  ::: Nodes  ASV_305 ASV_731 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 3
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 5
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 4
#  ::: Number of external Edges A+B: 5
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1117 ASV_1090
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  14 0.406923576163955
#  ::: Nodes  ASV_1117 ASV_1090 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 5 / 5
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 5 / 5
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 5 / 5
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 10
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 9
#  ::: Number of external Edges A+B: 10
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_170 ASV_272
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  15 0.400375461618099
#  ::: Nodes  ASV_170 ASV_272 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 4 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 4 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 4 / 4
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 8
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 7
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_754 ASV_516
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  16 0.399088715584371
#  ::: Nodes  ASV_754 ASV_516 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 3
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 5
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 4
#  ::: Number of external Edges A+B: 5
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1005 ASV_695
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  17 0.396793028833627
#  ::: Nodes  ASV_1005 ASV_695 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 8
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 8
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 8
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 10
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 9
#  ::: Number of external Edges A+B: 10
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1132 ASV_504
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  18 0.395683665571661
#  ::: Nodes  ASV_1132 ASV_504 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 1 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 1 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 1 / 4
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 4
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 3
#  ::: Number of external Edges A+B: 3
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_280 ASV_961
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  19 0.393798627694556
#  ::: Nodes  ASV_280 ASV_961 which contain:
#  ::: Number of Nodes A/B: 2 / 1
#  ::: Number of Edges A/B: 7 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 6 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 7 / 3
#  ::: Number of Nodes A+B: 3
#  ::: Number of Edges A+B: 10
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 8
#  ::: Number of external Edges A+B: 10
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_642 ASV_952
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  20 0.391629343373341
#  ::: Nodes  ASV_642 ASV_952 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 3 / 5
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 5
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 3 / 5
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 8
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 6
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_826 ASV_777
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  21 0.390607836173075
#  ::: Nodes  ASV_826 ASV_777 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 3 / 9
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 9
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 3 / 9
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 11
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 10
#  ::: Number of external Edges A+B: 10
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1436 ASV_464
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  22 0.389698930667383
#  ::: Nodes  ASV_1436 ASV_464 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 1 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 1 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 1 / 3
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 4
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 3
#  ::: Number of external Edges A+B: 4
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1228 ASV_1098
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  23 0.387732941210015
#  ::: Nodes  ASV_1228 ASV_1098 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 3 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 3 / 3
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 6
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 5
#  ::: Number of external Edges A+B: 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_362 ASV_677
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  24 0.385894670784653
#  ::: Nodes  ASV_362 ASV_677 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 5 / 5
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 5 / 5
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 5 / 5
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 9
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 8
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_428 ASV_631
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  25 0.384982581152792
#  ::: Nodes  ASV_428 ASV_631 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 5 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 5 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 5 / 3
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 7
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 6
#  ::: Number of external Edges A+B: 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_241 ASV_833
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  26 0.382241627299651
#  ::: Nodes  ASV_241 ASV_833 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 4 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 4 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 4 / 3
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 6
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 5
#  ::: Number of external Edges A+B: 5
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1214 ASV_1355
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  27 0.381926797410353
#  ::: Nodes  ASV_1214 ASV_1355 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 6 / 5
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 6 / 5
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 6 / 5
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 10
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 8
#  ::: Number of external Edges A+B: 9
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_143 ASV_876
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  28 0.379171557647126
#  ::: Nodes  ASV_143 ASV_876 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 7 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 7 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 7 / 4
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 11
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 10
#  ::: Number of external Edges A+B: 11
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1236 ASV_910
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  29 0.379077304528001
#  ::: Nodes  ASV_1236 ASV_910 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 7
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 7
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 7
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 8
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 7
#  ::: Number of external Edges A+B: 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_739 ASV_495
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  30 0.377358555896972
#  ::: Nodes  ASV_739 ASV_495 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 10 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 10 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 10 / 3
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 13
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 11
#  ::: Number of external Edges A+B: 13
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_552 ASV_890
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  31 0.377249149701596
#  ::: Nodes  ASV_552 ASV_890 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 4 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 4 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 4 / 3
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 7
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 6
#  ::: Number of external Edges A+B: 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1413 ASV_1101
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  32 0.376648133837173
#  ::: Nodes  ASV_1413 ASV_1101 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 4
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 6
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 5
#  ::: Number of external Edges A+B: 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_253 ASV_1111
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  33 0.375798858099019
#  ::: Nodes  ASV_253 ASV_1111 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 4 / 5
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 4 / 5
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 4 / 5
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 9
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 8
#  ::: Number of external Edges A+B: 9
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_750 ASV_418
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  34 0.37554551623838
#  ::: Nodes  ASV_750 ASV_418 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 7
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 7
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 7
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 8
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 7
#  ::: Number of external Edges A+B: 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_76 ASV_36
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  35 0.370420680896139
#  ::: Nodes  ASV_76 ASV_36 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 4 / 7
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 4 / 7
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 4 / 7
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 10
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 7
#  ::: Number of external Edges A+B: 9
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_879 ASV_970
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  36 0.366204165716829
#  ::: Nodes  ASV_879 ASV_970 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 3 / 1
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 1
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 3 / 1
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 4
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 3
#  ::: Number of external Edges A+B: 4
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1310 ASV_1230
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  37 0.365550038671802
#  ::: Nodes  ASV_1310 ASV_1230 which contain:
#  ::: Number of Nodes A/B: 2 / 1
#  ::: Number of Edges A/B: 8 / 1
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 7 / 1
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 8 / 1
#  ::: Number of Nodes A+B: 3
#  ::: Number of Edges A+B: 9
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 7
#  ::: Number of external Edges A+B: 9
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1088 ASV_253
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  38 0.365185380030102
#  ::: Nodes  ASV_1088 ASV_253 which contain:
#  ::: Number of Nodes A/B: 1 / 2
#  ::: Number of Edges A/B: 7 / 9
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 7 / 8
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 7 / 9
#  ::: Number of Nodes A+B: 3
#  ::: Number of Edges A+B: 16
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 14
#  ::: Number of external Edges A+B: 16
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1450 ASV_1317
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  39 0.363764023959173
#  ::: Nodes  ASV_1450 ASV_1317 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 3
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 5
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 4
#  ::: Number of external Edges A+B: 5
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1331 ASV_1114
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  40 0.362779202876862
#  ::: Nodes  ASV_1331 ASV_1114 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 4 / 6
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 4 / 6
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 4 / 6
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 9
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 8
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_562 ASV_280
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  41 0.362394710499543
#  ::: Nodes  ASV_562 ASV_280 which contain:
#  ::: Number of Nodes A/B: 1 / 3
#  ::: Number of Edges A/B: 6 / 10
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 6 / 8
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 6 / 10
#  ::: Number of Nodes A+B: 4
#  ::: Number of Edges A+B: 16
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 13
#  ::: Number of external Edges A+B: 16
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_690 ASV_656
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  42 0.362102941866729
#  ::: Nodes  ASV_690 ASV_656 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 6 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 6 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 6 / 4
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 9
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 7
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_170 ASV_165
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  43 0.354717687816942
#  ::: Nodes  ASV_170 ASV_165 which contain:
#  ::: Number of Nodes A/B: 2 / 1
#  ::: Number of Edges A/B: 8 / 6
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 7 / 6
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 8 / 6
#  ::: Number of Nodes A+B: 3
#  ::: Number of Edges A+B: 14
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 12
#  ::: Number of external Edges A+B: 14
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1178 ASV_213
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  44 0.354036590372436
#  ::: Nodes  ASV_1178 ASV_213 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 4 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 4 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 4 / 4
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 7
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 5
#  ::: Number of external Edges A+B: 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1216 ASV_305
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  45 0.351612888562647
#  ::: Nodes  ASV_1216 ASV_305 which contain:
#  ::: Number of Nodes A/B: 1 / 2
#  ::: Number of Edges A/B: 1 / 5
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 1 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 1 / 5
#  ::: Number of Nodes A+B: 3
#  ::: Number of Edges A+B: 6
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 4
#  ::: Number of external Edges A+B: 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_710 ASV_879
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  46 0.349768638452041
#  ::: Nodes  ASV_710 ASV_879 which contain:
#  ::: Number of Nodes A/B: 1 / 2
#  ::: Number of Edges A/B: 1 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 1 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 1 / 4
#  ::: Number of Nodes A+B: 3
#  ::: Number of Edges A+B: 5
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 3
#  ::: Number of external Edges A+B: 5
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_220 ASV_1401
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  47 0.349635975514749
#  ::: Nodes  ASV_220 ASV_1401 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 3 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 3 / 4
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 7
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 6
#  ::: Number of external Edges A+B: 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_315 ASV_282
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  48 0.349070175594046
#  ::: Nodes  ASV_315 ASV_282 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 7 / 6
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 7 / 6
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 7 / 6
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 12
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 11
#  ::: Number of external Edges A+B: 11
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1005 ASV_983
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  49 0.348493435597297
#  ::: Nodes  ASV_1005 ASV_983 which contain:
#  ::: Number of Nodes A/B: 2 / 1
#  ::: Number of Edges A/B: 10 / 7
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 9 / 7
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 10 / 7
#  ::: Number of Nodes A+B: 3
#  ::: Number of Edges A+B: 17
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 15
#  ::: Number of external Edges A+B: 17
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_148 ASV_82
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  50 0.348305535778628
#  ::: Nodes  ASV_148 ASV_82 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 5
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 5
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 5
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 7
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 6
#  ::: Number of external Edges A+B: 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_922 ASV_834
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  51 0.346673658103409
#  ::: Nodes  ASV_922 ASV_834 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 1 / 9
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 1 / 9
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 1 / 9
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 9
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 8
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1458 ASV_1413
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  52 0.346670523629208
#  ::: Nodes  ASV_1458 ASV_1413 which contain:
#  ::: Number of Nodes A/B: 1 / 2
#  ::: Number of Edges A/B: 1 / 6
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 1 / 5
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 1 / 6
#  ::: Number of Nodes A+B: 3
#  ::: Number of Edges A+B: 7
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 5
#  ::: Number of external Edges A+B: 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_810 ASV_590
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  53 0.345771243421352
#  ::: Nodes  ASV_810 ASV_590 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 2
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 2
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 2
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 4
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 3
#  ::: Number of external Edges A+B: 4
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_821 ASV_377
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  54 0.345734859928637
#  ::: Nodes  ASV_821 ASV_377 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 2 / 6
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 2 / 6
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 2 / 6
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 8
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 7
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1200 ASV_1256
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  55 0.345336773251774
#  ::: Nodes  ASV_1200 ASV_1256 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 11 / 2
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 11 / 2
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 11 / 2
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 12
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 11
#  ::: Number of external Edges A+B: 11
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1400 ASV_710
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  56 0.344290200046614
#  ::: Nodes  ASV_1400 ASV_710 which contain:
#  ::: Number of Nodes A/B: 1 / 3
#  ::: Number of Edges A/B: 1 / 5
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 1 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 1 / 5
#  ::: Number of Nodes A+B: 4
#  ::: Number of Edges A+B: 6
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 3
#  ::: Number of external Edges A+B: 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_385 ASV_562
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  57 0.343451464037895
#  ::: Nodes  ASV_385 ASV_562 which contain:
#  ::: Number of Nodes A/B: 1 / 4
#  ::: Number of Edges A/B: 3 / 16
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 13
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 3 / 16
#  ::: Number of Nodes A+B: 5
#  ::: Number of Edges A+B: 19
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 15
#  ::: Number of external Edges A+B: 19
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_863 ASV_323
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  58 0.343238591219726
#  ::: Nodes  ASV_863 ASV_323 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 8 / 4
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 8 / 4
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 8 / 4
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 11
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 10
#  ::: Number of external Edges A+B: 10
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1400 ASV_738
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  59 0.341550983368293
#  ::: Nodes  ASV_1400 ASV_738 which contain:
#  ::: Number of Nodes A/B: 4 / 1
#  ::: Number of Edges A/B: 6 / 1
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 1
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 6 / 1
#  ::: Number of Nodes A+B: 5
#  ::: Number of Edges A+B: 7
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 3
#  ::: Number of external Edges A+B: 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_754 ASV_1433
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  60 0.340292767952249
#  ::: Nodes  ASV_754 ASV_1433 which contain:
#  ::: Number of Nodes A/B: 2 / 1
#  ::: Number of Edges A/B: 5 / 1
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 4 / 1
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 5 / 1
#  ::: Number of Nodes A+B: 3
#  ::: Number of Edges A+B: 6
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 4
#  ::: Number of external Edges A+B: 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1400 ASV_897
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  61 0.339907453361301
#  ::: Nodes  ASV_1400 ASV_897 which contain:
#  ::: Number of Nodes A/B: 5 / 1
#  ::: Number of Edges A/B: 7 / 1
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 1
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 7 / 1
#  ::: Number of Nodes A+B: 6
#  ::: Number of Edges A+B: 8
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 3
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_437 ASV_1096
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  62 0.33975414800166
#  ::: Nodes  ASV_437 ASV_1096 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 7 / 3
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 7 / 3
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 7 / 3
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 10
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 9
#  ::: Number of external Edges A+B: 10
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_989 ASV_195
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  63 0.339686424709728
#  ::: Nodes  ASV_989 ASV_195 which contain:
#  ::: Number of Nodes A/B: 1 / 1
#  ::: Number of Edges A/B: 3 / 7
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 7
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 3 / 7
#  ::: Number of Nodes A+B: 2
#  ::: Number of Edges A+B: 9
#  ::: Number of internal Nodes A+B: 2
#  ::: Number of internal Edges A+B: 1
#  ::: Number of external Nodes A+B: 8
#  ::: Number of external Edges A+B: 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_385 ASV_501
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  64 0.339008979557787
#  ::: Nodes  ASV_385 ASV_501 which contain:
#  ::: Number of Nodes A/B: 5 / 1
#  ::: Number of Edges A/B: 19 / 1
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 15 / 1
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 19 / 1
#  ::: Number of Nodes A+B: 6
#  ::: Number of Edges A+B: 20
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 15
#  ::: Number of external Edges A+B: 20
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1400 ASV_1338
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  65 0.338811766689973
#  ::: Nodes  ASV_1400 ASV_1338 which contain:
#  ::: Number of Nodes A/B: 6 / 1
#  ::: Number of Edges A/B: 8 / 1
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 3 / 1
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 8 / 1
#  ::: Number of Nodes A+B: 7
#  ::: Number of Edges A+B: 9
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 3
#  ::: Number of external Edges A+B: 9
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_385 ASV_1302
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  66 0.338062949378428
#  ::: Nodes  ASV_385 ASV_1302 which contain:
#  ::: Number of Nodes A/B: 6 / 1
#  ::: Number of Edges A/B: 20 / 1
#  ::: Number of Internal Nodes A/B: 0 / 0
#  ::: Number of External Nodes A/B: 15 / 1
#  ::: Number of Internal Edges A/B: 0 / 0
#  ::: Number of External Edges A/B: 20 / 1
#  ::: Number of Nodes A+B: 7
#  ::: Number of Edges A+B: 21
#  ::: Number of internal Nodes A+B: 0
#  ::: Number of internal Edges A+B: 0
#  ::: Number of external Nodes A+B: 15
#  ::: Number of external Edges A+B: 21
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1400 ASV_1115
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  67 0.33802913335331
#  ::: Nodes  ASV_1400 ASV_1115 which contain:
# ...
#  ::: Number of Internal Edges A/B: 40 / 41
#  ::: Number of External Edges A/B: 135 / 127
#  ::: Number of Nodes A+B: 72
#  ::: Number of Edges A+B: 329
#  ::: Number of internal Nodes A+B: 71
#  ::: Number of internal Edges A+B: 95
#  ::: Number of external Nodes A+B: 172
#  ::: Number of external Edges A+B: 234
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_754 ASV_994
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  880 0.00470797961001365
#  ::: Nodes  ASV_754 ASV_994 which contain:
#  ::: Number of Nodes A/B: 15 / 22
#  ::: Number of Edges A/B: 47 / 97
#  ::: Number of Internal Nodes A/B: 15 / 19
#  ::: Number of External Nodes A/B: 32 / 63
#  ::: Number of Internal Edges A/B: 14 / 22
#  ::: Number of External Edges A/B: 33 / 75
#  ::: Number of Nodes A+B: 37
#  ::: Number of Edges A+B: 138
#  ::: Number of internal Nodes A+B: 37
#  ::: Number of internal Edges A+B: 42
#  ::: Number of external Nodes A+B: 86
#  ::: Number of external Edges A+B: 96
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_853 ASV_546
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  881 0.00448268655842067
#  ::: Nodes  ASV_853 ASV_546 which contain:
#  ::: Number of Nodes A/B: 22 / 42
#  ::: Number of Edges A/B: 104 / 183
#  ::: Number of Internal Nodes A/B: 21 / 42
#  ::: Number of External Nodes A/B: 79 / 119
#  ::: Number of Internal Edges A/B: 22 / 46
#  ::: Number of External Edges A/B: 82 / 137
#  ::: Number of Nodes A+B: 64
#  ::: Number of Edges A+B: 278
#  ::: Number of internal Nodes A+B: 63
#  ::: Number of internal Edges A+B: 77
#  ::: Number of external Nodes A+B: 169
#  ::: Number of external Edges A+B: 201
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_629 ASV_240
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  882 0.00424712039632875
#  ::: Nodes  ASV_629 ASV_240 which contain:
#  ::: Number of Nodes A/B: 36 / 12
#  ::: Number of Edges A/B: 171 / 54
#  ::: Number of Internal Nodes A/B: 36 / 12
#  ::: Number of External Nodes A/B: 101 / 41
#  ::: Number of Internal Edges A/B: 47 / 11
#  ::: Number of External Edges A/B: 124 / 43
#  ::: Number of Nodes A+B: 48
#  ::: Number of Edges A+B: 222
#  ::: Number of internal Nodes A+B: 48
#  ::: Number of internal Edges A+B: 61
#  ::: Number of external Nodes A+B: 134
#  ::: Number of external Edges A+B: 161
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_683 ASV_1301
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  883 0.00413499167521952
#  ::: Nodes  ASV_683 ASV_1301 which contain:
#  ::: Number of Nodes A/B: 39 / 19
#  ::: Number of Edges A/B: 205 / 74
#  ::: Number of Internal Nodes A/B: 39 / 19
#  ::: Number of External Nodes A/B: 124 / 55
#  ::: Number of Internal Edges A/B: 50 / 18
#  ::: Number of External Edges A/B: 155 / 56
#  ::: Number of Nodes A+B: 58
#  ::: Number of Edges A+B: 276
#  ::: Number of internal Nodes A+B: 58
#  ::: Number of internal Edges A+B: 71
#  ::: Number of external Nodes A+B: 163
#  ::: Number of external Edges A+B: 205
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_7 ASV_901
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  884 0.00378877358710089
#  ::: Nodes  ASV_7 ASV_901 which contain:
#  ::: Number of Nodes A/B: 94 / 41
#  ::: Number of Edges A/B: 379 / 214
#  ::: Number of Internal Nodes A/B: 94 / 39
#  ::: Number of External Nodes A/B: 148 / 128
#  ::: Number of Internal Edges A/B: 164 / 48
#  ::: Number of External Edges A/B: 215 / 166
#  ::: Number of Nodes A+B: 135
#  ::: Number of Edges A+B: 553
#  ::: Number of internal Nodes A+B: 135
#  ::: Number of internal Edges A+B: 252
#  ::: Number of external Nodes A+B: 207
#  ::: Number of external Edges A+B: 301
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_629 ASV_47
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  885 0.00376424259480711
#  ::: Nodes  ASV_629 ASV_47 which contain:
#  ::: Number of Nodes A/B: 48 / 25
#  ::: Number of Edges A/B: 222 / 145
#  ::: Number of Internal Nodes A/B: 48 / 22
#  ::: Number of External Nodes A/B: 134 / 105
#  ::: Number of Internal Edges A/B: 61 / 24
#  ::: Number of External Edges A/B: 161 / 121
#  ::: Number of Nodes A+B: 73
#  ::: Number of Edges A+B: 355
#  ::: Number of internal Nodes A+B: 71
#  ::: Number of internal Edges A+B: 97
#  ::: Number of external Nodes A+B: 204
#  ::: Number of external Edges A+B: 258
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1021 ASV_655
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  886 0.00375680025855431
#  ::: Nodes  ASV_1021 ASV_655 which contain:
#  ::: Number of Nodes A/B: 31 / 40
#  ::: Number of Edges A/B: 157 / 198
#  ::: Number of Internal Nodes A/B: 29 / 40
#  ::: Number of External Nodes A/B: 101 / 125
#  ::: Number of Internal Edges A/B: 43 / 50
#  ::: Number of External Edges A/B: 114 / 148
#  ::: Number of Nodes A+B: 71
#  ::: Number of Edges A+B: 348
#  ::: Number of internal Nodes A+B: 69
#  ::: Number of internal Edges A+B: 100
#  ::: Number of external Nodes A+B: 187
#  ::: Number of external Edges A+B: 248
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1382 ASV_637
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  887 0.00369860258983486
#  ::: Nodes  ASV_1382 ASV_637 which contain:
#  ::: Number of Nodes A/B: 42 / 35
#  ::: Number of Edges A/B: 222 / 185
#  ::: Number of Internal Nodes A/B: 41 / 35
#  ::: Number of External Nodes A/B: 144 / 112
#  ::: Number of Internal Edges A/B: 51 / 45
#  ::: Number of External Edges A/B: 171 / 140
#  ::: Number of Nodes A+B: 77
#  ::: Number of Edges A+B: 393
#  ::: Number of internal Nodes A+B: 77
#  ::: Number of internal Edges A+B: 110
#  ::: Number of external Nodes A+B: 210
#  ::: Number of external Edges A+B: 283
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_1351 ASV_146
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  888 0.00329172251403366
#  ::: Nodes  ASV_1351 ASV_146 which contain:
#  ::: Number of Nodes A/B: 72 / 72
#  ::: Number of Edges A/B: 329 / 370
#  ::: Number of Internal Nodes A/B: 71 / 72
#  ::: Number of External Nodes A/B: 172 / 171
#  ::: Number of Internal Edges A/B: 95 / 133
#  ::: Number of External Edges A/B: 234 / 237
#  ::: Number of Nodes A+B: 144
#  ::: Number of Edges A+B: 656
#  ::: Number of internal Nodes A+B: 143
#  ::: Number of internal Edges A+B: 271
#  ::: Number of external Nodes A+B: 248
#  ::: Number of external Edges A+B: 385
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_853 ASV_406
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  889 0.00321842475835669
#  ::: Nodes  ASV_853 ASV_406 which contain:
#  ::: Number of Nodes A/B: 64 / 39
#  ::: Number of Edges A/B: 278 / 171
#  ::: Number of Internal Nodes A/B: 63 / 38
#  ::: Number of External Nodes A/B: 169 / 111
#  ::: Number of Internal Edges A/B: 77 / 44
#  ::: Number of External Edges A/B: 201 / 127
#  ::: Number of Nodes A+B: 103
#  ::: Number of Edges A+B: 441
#  ::: Number of internal Nodes A+B: 101
#  ::: Number of internal Edges A+B: 129
#  ::: Number of external Nodes A+B: 240
#  ::: Number of external Edges A+B: 312
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_384 ASV_629
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  890 0.00303312465861141
#  ::: Nodes  ASV_384 ASV_629 which contain:
#  ::: Number of Nodes A/B: 75 / 73
#  ::: Number of Edges A/B: 342 / 355
#  ::: Number of Internal Nodes A/B: 75 / 71
#  ::: Number of External Nodes A/B: 196 / 204
#  ::: Number of Internal Edges A/B: 101 / 97
#  ::: Number of External Edges A/B: 241 / 258
#  ::: Number of Nodes A+B: 148
#  ::: Number of Edges A+B: 662
#  ::: Number of internal Nodes A+B: 146
#  ::: Number of internal Edges A+B: 233
#  ::: Number of external Nodes A+B: 296
#  ::: Number of external Edges A+B: 429
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_683 ASV_1382
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  891 0.00281022316600533
#  ::: Nodes  ASV_683 ASV_1382 which contain:
#  ::: Number of Nodes A/B: 58 / 77
#  ::: Number of Edges A/B: 276 / 393
#  ::: Number of Internal Nodes A/B: 58 / 77
#  ::: Number of External Nodes A/B: 163 / 210
#  ::: Number of Internal Edges A/B: 71 / 110
#  ::: Number of External Edges A/B: 205 / 283
#  ::: Number of Nodes A+B: 135
#  ::: Number of Edges A+B: 637
#  ::: Number of internal Nodes A+B: 135
#  ::: Number of internal Edges A+B: 213
#  ::: Number of external Nodes A+B: 284
#  ::: Number of external Edges A+B: 424
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_256 ASV_7
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  892 0.00276696778084253
#  ::: Nodes  ASV_256 ASV_7 which contain:
#  ::: Number of Nodes A/B: 82 / 135
#  ::: Number of Edges A/B: 344 / 553
#  ::: Number of Internal Nodes A/B: 80 / 135
#  ::: Number of External Nodes A/B: 168 / 207
#  ::: Number of Internal Edges A/B: 133 / 252
#  ::: Number of External Edges A/B: 211 / 301
#  ::: Number of Nodes A+B: 217
#  ::: Number of Edges A+B: 843
#  ::: Number of internal Nodes A+B: 216
#  ::: Number of internal Edges A+B: 439
#  ::: Number of external Nodes A+B: 260
#  ::: Number of external Edges A+B: 404
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_683 ASV_1021
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  893 0.00253007593171279
#  ::: Nodes  ASV_683 ASV_1021 which contain:
#  ::: Number of Nodes A/B: 135 / 71
#  ::: Number of Edges A/B: 637 / 348
#  ::: Number of Internal Nodes A/B: 135 / 69
#  ::: Number of External Nodes A/B: 284 / 187
#  ::: Number of Internal Edges A/B: 213 / 100
#  ::: Number of External Edges A/B: 424 / 248
#  ::: Number of Nodes A+B: 206
#  ::: Number of Edges A+B: 932
#  ::: Number of internal Nodes A+B: 206
#  ::: Number of internal Edges A+B: 366
#  ::: Number of external Nodes A+B: 332
#  ::: Number of external Edges A+B: 566
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_384 ASV_853
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  894 0.00240144548921304
#  ::: Nodes  ASV_384 ASV_853 which contain:
#  ::: Number of Nodes A/B: 148 / 103
#  ::: Number of Edges A/B: 662 / 441
#  ::: Number of Internal Nodes A/B: 146 / 101
#  ::: Number of External Nodes A/B: 296 / 240
#  ::: Number of Internal Edges A/B: 233 / 129
#  ::: Number of External Edges A/B: 429 / 312
#  ::: Number of Nodes A+B: 251
#  ::: Number of Edges A+B: 1031
#  ::: Number of internal Nodes A+B: 251
#  ::: Number of internal Edges A+B: 434
#  ::: Number of external Nodes A+B: 336
#  ::: Number of external Edges A+B: 597
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_384 ASV_696
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  895 0.00235034728161379
#  ::: Nodes  ASV_384 ASV_696 which contain:
#  ::: Number of Nodes A/B: 251 / 36
#  ::: Number of Edges A/B: 1031 / 130
#  ::: Number of Internal Nodes A/B: 251 / 36
#  ::: Number of External Nodes A/B: 336 / 86
#  ::: Number of Internal Edges A/B: 434 / 36
#  ::: Number of External Edges A/B: 597 / 94
#  ::: Number of Nodes A+B: 287
#  ::: Number of Edges A+B: 1129
#  ::: Number of internal Nodes A+B: 287
#  ::: Number of internal Edges A+B: 502
#  ::: Number of external Nodes A+B: 341
#  ::: Number of external Edges A+B: 627
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_683 ASV_1351
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  896 0.00217491310430604
#  ::: Nodes  ASV_683 ASV_1351 which contain:
#  ::: Number of Nodes A/B: 206 / 144
#  ::: Number of Edges A/B: 932 / 656
#  ::: Number of Internal Nodes A/B: 206 / 143
#  ::: Number of External Nodes A/B: 332 / 248
#  ::: Number of Internal Edges A/B: 366 / 271
#  ::: Number of External Edges A/B: 566 / 385
#  ::: Number of Nodes A+B: 350
#  ::: Number of Edges A+B: 1454
#  ::: Number of internal Nodes A+B: 350
#  ::: Number of internal Edges A+B: 771
#  ::: Number of external Nodes A+B: 343
#  ::: Number of external Edges A+B: 683
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_683 ASV_384
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  897 0.00197071644406972
#  ::: Nodes  ASV_683 ASV_384 which contain:
#  ::: Number of Nodes A/B: 350 / 287
#  ::: Number of Edges A/B: 1454 / 1129
#  ::: Number of Internal Nodes A/B: 350 / 287
#  ::: Number of External Nodes A/B: 343 / 341
#  ::: Number of Internal Edges A/B: 771 / 502
#  ::: Number of External Edges A/B: 683 / 627
#  ::: Number of Nodes A+B: 637
#  ::: Number of Edges A+B: 2161
#  ::: Number of internal Nodes A+B: 637
#  ::: Number of internal Edges A+B: 1695
#  ::: Number of external Nodes A+B: 205
#  ::: Number of external Edges A+B: 466
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_683 ASV_754
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  898 0.00148188686840421
#  ::: Nodes  ASV_683 ASV_754 which contain:
#  ::: Number of Nodes A/B: 637 / 37
#  ::: Number of Edges A/B: 2161 / 138
#  ::: Number of Internal Nodes A/B: 637 / 37
#  ::: Number of External Nodes A/B: 205 / 86
#  ::: Number of Internal Edges A/B: 1695 / 42
#  ::: Number of External Edges A/B: 466 / 96
#  ::: Number of Nodes A+B: 674
#  ::: Number of Edges A+B: 2226
#  ::: Number of internal Nodes A+B: 674
#  ::: Number of internal Edges A+B: 1810
#  ::: Number of external Nodes A+B: 181
#  ::: Number of external Edges A+B: 416
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_683 ASV_256
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  899 0.00143896001102128
#  ::: Nodes  ASV_683 ASV_256 which contain:
#  ::: Number of Nodes A/B: 674 / 217
#  ::: Number of Edges A/B: 2226 / 843
#  ::: Number of Internal Nodes A/B: 674 / 216
#  ::: Number of External Nodes A/B: 181 / 260
#  ::: Number of Internal Edges A/B: 1810 / 439
#  ::: Number of External Edges A/B: 416 / 404
#  ::: Number of Nodes A+B: 891
#  ::: Number of Edges A+B: 2668
#  ::: Number of internal Nodes A+B: 891
#  ::: Number of internal Edges A+B: 2650
#  ::: Number of external Nodes A+B: 6
#  ::: Number of external Edges A+B: 18
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ** JOINING: *************************
# ASV_683 ASV_651
# ************************************
#
# ~~~ Results for A
# ~~~ Results for B
# ~~~ Clustering at Step/Thr  900 0.00120233383707366
#  ::: Nodes  ASV_683 ASV_651 which contain:
#  ::: Number of Nodes A/B: 891 / 10
#  ::: Number of Edges A/B: 2668 / 28
#  ::: Number of Internal Nodes A/B: 891 / 10
#  ::: Number of External Nodes A/B: 6 / 18
#  ::: Number of Internal Edges A/B: 2650 / 10
#  ::: Number of External Edges A/B: 18 / 18
#  ::: Number of Nodes A+B: 901
#  ::: Number of Edges A+B: 2678
#  ::: Number of internal Nodes A+B: 901
#  ::: Number of internal Edges A+B: 2678
#  ::: Number of external Nodes A+B: 0
#  ::: Number of external Edges A+B: 0
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# WARNING ~~~~~~~~~~~~~~~~~~~~~~~~~~
# ::: Stopping clustering at Step: 900
# ::: No more significant relations were found
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ~~~ Done!
#
# ****************************
# ** Program finished
# ** Check your results
# ** Bye!
# ****************************

# %% [markdown]
# The code in the below cell is copied and modified from nodeLinkage_analysis.R found within the functionInk repository. Please switch to the R kernel to run it.

# %%
# Third step - identifying the optimal partition

library(ggplot2)
library(here)

# --- Path to dir of history compact file
dir="." #  path to dir of history compact file relative to the root of the repo (e.g. fix to "." if it is located in the root of the directory)

# --- Name of the history file
file.hist="HistCompact-NL_Average_NoStop_final1_class1_network_data.tsv" #"history file name"

src.dir=here("scripts","analysis_R")
root.dir=here()
setwd(src.dir)
source("extractPartDensity.R")
if(dir == "."){
  setwd(root.dir)
}else{
  setwd(here(dir))
}

hist.comp=read.table(file=file.hist,sep="\t",header = TRUE) # for current NodeLink.pl version (Dec 2018)

part_density=extractPartDensity(hist.comp)

part_density$total_dens # maximum of the total partition density
part_density$int_dens # maximum of the internal partition density
part_density$ext_dens # maximum of the external partition density
part_density$total_dens_step # step of the clustering in which the maximum of the total partition density was found
part_density$int_dens_step # step of the clustering in which the maximum of the internal partition density was found
part_density$ext_dens_step # step of the clustering in which the maximum of the external partition density was found
# Out:
# here() starts at /home/matthew/Documents/ResearchProject/ResearchProjectRepository
# Error in setwd(src.dir): cannot change working directory
# Traceback:
#
# 1. setwd(src.dir)

# %%
# Moving some of the output files to the data directory
import os
source_file = 'Nodes-Similarities_final1_class1_network_data.tsv'
destination_directory = '../../data'
file_name = os.path.basename(source_file)
destination_path = os.path.join(destination_directory, file_name)
os.rename(source_file, destination_path)

source_file = 'HistCompact-NL_Average_NoStop_final1_class1_network_data.tsv'
destination_directory = '../../data'
file_name = os.path.basename(source_file)
destination_path = os.path.join(destination_directory, file_name)
os.rename(source_file, destination_path)

source_file = 'Nodes-Similarities_final1_class1_network_data.tsv'
destination_directory = '../../data'
file_name = os.path.basename(source_file)
destination_path = os.path.join(destination_directory, file_name)
os.rename(source_file, destination_path)

# Moving the final output files to the results directory
